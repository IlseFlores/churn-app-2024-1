# %%
import numpy as np

import pandas as pd

data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
mask_missing = data["TotalCharges"]== " "
data.loc[mask_missing, "TotalCharges"] = data.loc[mask_missing, "MonthlyCharges"]

# %%
data["TotalCharges"] = data["TotalCharges"].astype(float)

# %%
num = data.select_dtypes(include = ['int64','float64'])
num.hist()
# Out:
# array([[<Axes: title={'center': 'SeniorCitizen'}>,
#         <Axes: title={'center': 'tenure'}>],
#        [<Axes: title={'center': 'MonthlyCharges'}>,
#         <Axes: title={'center': 'TotalCharges'}>]], dtype=object)

# %%
df_raw = data.drop(["customerID","Churn"], axis = 1)

# %%
df_final=pd.get_dummies(df_raw)

# %%
df_churn = data["Churn"].apply(lambda x: 1 if x=="yes" else 0)
df_final = pd.concat([df_final, df_churn], axis = 1)

# %%
df_final.head(30)
# Out:
#     SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Female  \
# 0               0       1           29.85         29.85           True
# 1               0      34           56.95       1889.50          False
# 2               0       2           53.85        108.15          False
# 3               0      45           42.30       1840.75          False
# 4               0       2           70.70        151.65           True
# 5               0       8           99.65        820.50           True
# 6               0      22           89.10       1949.40          False
# 7               0      10           29.75        301.90           True
# 8               0      28          104.80       3046.05           True
# 9               0      62           56.15       3487.95          False
# 10              0      13           49.95        587.45          False
# 11              0      16           18.95        326.80          False
# 12              0      58          100.35       5681.10          False
# 13              0      49          103.70       5036.30          False
# 14              0      25          105.50       2686.05          False
# 15              0      69          113.25       7895.15           True
# 16              0      52           20.65       1022.95           True
# 17              0      71          106.70       7382.25          False
# 18              0      10           55.20        528.35           True
# 19              0      21           90.05       1862.90           True
# 20              1       1           39.65         39.65          False
# 21              0      12           19.80        202.25          False
# 22              0       1           20.15         20.15          False
# 23              0      58           59.90       3505.10           True
# 24              0      49           59.60       2970.30          False
# 25              0      30           55.30       1530.60           True
# 26              0      47           99.35       4749.15          False
# 27              0       1           30.20         30.20          False
# 28              0      72           90.25       6369.45          False
# 29              0      17           64.70       1093.10           True
#
#     gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0         False       False         True           True           False  ...
# 1          True        True        False           True           False  ...
# 2          True        True        False           True           False  ...
# 3          True        True        False           True           False  ...
# 4         False        True        False           True           False  ...
# 5         False        True        False           True           False  ...
# 6          True        True        False          False            True  ...
# 7         False        True        False           True           False  ...
# 8         False       False         True           True           False  ...
# 9          True        True        False          False            True  ...
# 10         True       False         True          False            True  ...
# 11         True        True        False           True           False  ...
# 12         True       False         True           True           False  ...
# 13         True        True        False           True           False  ...
# 14         True        True        False           True           False  ...
# 15        False       False         True          False            True  ...
# 16        False        True        False           True           False  ...
# 17         True        True        False          False            True  ...
# 18        False       False         True          False            True  ...
# 19        False        True        False           True           False  ...
# 20         True        True        False           True           False  ...
# 21         True       False         True           True           False  ...
# 22         True        True        False           True           False  ...
# 23        False       False         True           True           False  ...
# 24         True       False         True          False            True  ...
# 25        False        True        False           True           False  ...
# 26         True       False         True          False            True  ...
# 27         True       False         True          False            True  ...
# 28         True       False         True           True           False  ...
# 29        False        True        False          False            True  ...
#
#     Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 0                      True              False              False
# 1                     False               True              False
# 2                      True              False              False
# 3                     False               True              False
# 4                      True              False              False
# 5                      True              False              False
# 6                      True              False              False
# 7                      True              False              False
# 8                      True              False              False
# 9                     False               True              False
# 10                     True              False              False
# 11                    False              False               True
# 12                    False               True              False
# 13                     True              False              False
# 14                     True              False              False
# 15                    False              False               True
# 16                    False               True              False
# 17                    False              False               True
# 18                     True              False              False
# 19                     True              False              False
# 20                     True              False              False
# 21                    False               True              False
# 22                     True              False              False
# 23                    False              False               True
# 24                     True              False              False
# 25                     True              False              False
# 26                     True              False              False
# 27                     True              False              False
# 28                    False              False               True
# 29                     True              False              False
#
#     PaperlessBilling_No  PaperlessBilling_Yes  \
# 0                 False                  True
# 1                  True                 False
# 2                 False                  True
# 3                  True                 False
# 4                 False                  True
# 5                 False                  True
# 6                 False                  True
# 7                  True                 False
# 8                 False                  True
# 9                  True                 False
# 10                False                  True
# 11                 True                 False
# 12                 True                 False
# 13                False                  True
# 14                False                  True
# 15                 True                 False
# 16                 True                 False
# 17                 True                 False
# 18                 True                 False
# 19                False                  True
# 20                False                  True
# 21                 True                 False
# 22                 True                 False
# 23                False                  True
# 24                 True                 False
# 25                False                  True
# 26                False                  True
# 27                 True                 False
# 28                False                  True
# 29                False                  True
#
#     PaymentMethod_Bank transfer (automatic)  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
# 5                                     False
# 6                                     False
# 7                                     False
# 8                                     False
# 9                                      True
# 10                                    False
# 11                                    False
# 12                                    False
# 13                                     True
# 14                                    False
# 15                                    False
# 16                                    False
# 17                                     True
# 18                                    False
# 19                                    False
# 20                                    False
# 21                                     True
# 22                                    False
# 23                                    False
# 24                                    False
# 25                                     True
# 26                                    False
# 27                                    False
# 28                                    False
# 29                                    False
#
#     PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                   False                            True
# 1                                   False                           False
# 2                                   False                           False
# 3                                   False                           False
# 4                                   False                            True
# 5                                   False                            True
# 6                                    True                           False
# 7                                   False                           False
# 8                                   False                            True
# 9                                   False                           False
# 10                                  False                           False
# 11                                   True                           False
# 12                                   True                           False
# 13                                  False                           False
# 14                                  False                            True
# 15                                   True                           False
# 16                                  False                           False
# 17                                  False                           False
# 18                                   True                           False
# 19                                  False                            True
# 20                                  False                            True
# 21                                  False                           False
# 22                                  False                           False
# 23                                   True                           False
# 24                                   True                           False
# 25                                  False                           False
# 26                                  False                            True
# 27                                  False                            True
# 28                                   True                           False
# 29                                  False                           False
#
#     PaymentMethod_Mailed check  Churn
# 0                        False      0
# 1                         True      0
# 2                         True      0
# 3                        False      0
# 4                        False      0
# 5                        False      0
# 6                        False      0
# 7                         True      0
# 8                        False      0
# 9                        False      0
# 10                        True      0
# 11                       False      0
# 12                       False      0
# 13                       False      0
# 14                       False      0
# 15                       False      0
# 16                        True      0
# 17                       False      0
# 18                       False      0
# 19                       False      0
# 20                       False      0
# 21                       False      0
# 22                        True      0
# 23                       False      0
# 24                       False      0
# 25                       False      0
# 26                       False      0
# 27                       False      0
# 28                       False      0
# 29                        True      0
#
# [30 rows x 46 columns]

# %%
df_final.to_csv("../data/processed/df_final.csv" ,index = False)
